# %%
9import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\isman\Downloads\diabetes 22nd May (1).csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df,markers='+')
plt.show()

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
plt.scatter(df['Age'],df['Pregnancies'])
plt.xlabel("Age")
plt.ylabel("pregnancies")
# Out:
# Text(0, 0.5, 'pregnancies')

# %%
plt.scatter(df['Age'],df['Outcome'],marker='+')
plt.xlabel("Age")
plt.ylabel("Outcome")
# Out:
# Text(0, 0.5, 'Outcome')

# %%
sns.histplot(df['DiabetesPedigreeFunction'],kde=True)
skewness=df['DiabetesPedigreeFunction'].skew()
kurtosis=df['DiabetesPedigreeFunction'].kurt()
print("skewness:",skewness)
print("kurtosis:",kurtosis)
# Out:
# skewness: 1.919911066307204
# kurtosis: 5.5949535279830584

# %%
sns.boxplot(x='DiabetesPedigreeFunction',data=df)
plt.show()

# %%
sns.boxplot(x='Outcome',y='DiabetesPedigreeFunction',data=df)
plt.show()

# %%
sns.pairplot(data=df, hue="Outcome")  # Correct syntax
plt.show()

# %%
corr_matrix=df.corr(numeric_only=True)
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %% [raw]
# from sklearn.model_selection import train_test_split

# %%
x=df.drop('Outcome',axis=1)
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [raw]
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 721            1      114             66             36      200  38.1
# 261            3      141              0              0        0  30.0
# 564            0       91             80              0        0  32.4
# 408            8      197             74              0        0  25.9
# 709            2       93             64             32      160  38.0
# ..           ...      ...            ...            ...      ...   ...
# 279            2      108             62             10      278  25.3
# 401            6      137             61              0        0  24.2
# 421            2       94             68             18       76  26.0
# 687            1      107             50             19        0  28.3
# 449            0      120             74             18       63  30.5
#
#      DiabetesPedigreeFunction  Age
# 721                     0.289   21
# 261                     0.761   27
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 612            7      168             88             42      321  38.2
# 121            6      111             64             39        0  34.2
# 173            1       79             60             42       48  43.5
# 487            0      173             78             32      265  46.5
# 191            9      123             70             44       94  33.1
# ..           ...      ...            ...            ...      ...   ...
# 748            3      187             70             22      200  36.4
# 342            1        0             68             35        0  32.0
# 300            0      167              0              0        0  32.3
# 529            0      111             65              0        0  24.6
# 296            2      146             70             38      360  28.0
#
#      DiabetesPedigreeFunction  Age
# 612                     0.787   40
# 121                     0.260   24
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# -0.8863819876345083

# %%
model.coef_
# Out:
# array([ 1.76066865e-02,  6.02081554e-03, -2.75365743e-03,  6.63731687e-06,
#        -1.76863581e-04,  1.42963115e-02,  1.09197460e-01,  4.27307510e-03])

# %%
y_train_pred=model.predict(x_train)
y_test_pred=model.predict(x_test)
x_test
# Out:
#      Age
# 361   63
# 400   31
# 534   24
# 670   49
# 246   41
# ..   ...
# 394   31
# 447   26
# 650   23
# 48    31
# 663   40
#
# [231 rows x 1 columns]

# %%
x_train
# Out:
#      Age
# 41    37
# 551   25
# 180   32
# 387   45
# 342   22
# ..   ...
# 22    41
# 141   38
# 254   44
# 767   23
# 595   22
#
# [537 rows x 1 columns]

# %%
print(y_test_pred)
# Out:
# [ 0.75252604  0.33147243  0.22764515  0.93295406  0.48852011  0.69967126
#   0.46459893  0.29064823  0.80439737  0.24714894  0.48975638  0.62552746
#   0.00412906  0.49483913  1.02168549  0.21058643  0.24089119  0.61306687
#   0.36069054  0.90910948  0.45526931  0.73538877  0.35868639  0.35765051
#   0.37934419  0.13123755  0.17310336  0.24175972 -0.1856439   0.67049288
#   1.05093896  0.38283528  0.32322476  0.00766709  0.25092281  0.43713079
#   0.26069373  0.85666091  0.3069324   0.28318041  0.15476025  0.22139405
#   0.92181469  0.52293005  0.72596305  0.4845014   0.68765461  0.66681096
#   0.26029672  0.13826135  0.24510499  0.5461634   0.32529066  0.41763428
#   0.75072728 -0.05325623  0.43421865  0.36478799  0.4775698   0.38795724
#   0.43943411  0.33687576  0.19912721  0.32625796  0.38819695  0.84663448
#   0.45468843  0.21887314  0.34705848  0.63118124  0.19384892  0.30294246
#   0.6252901   0.4904775   0.17104303 -0.08165421  0.45743782  0.74695128
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score  # Correct function name

# %%
lr_train_mse=mean_squared_error(y_train,y_train_pred)
lr_train_r2=r2_score(y_train,y_train_pred)

# %%
lr_test_mse=mean_squared_error(y_test,y_test_pred)
lr_test_r2=r2_score(y_test,y_test_pred)

# %%
print(lr_train_mse)
print(lr_train_r2)
print(lr_test_mse)
print(lr_test_r2)
# Out:
# 0.1525033467788797
# 0.32835103128212006
# 0.18396455908668202
# 0.19205491050004608
